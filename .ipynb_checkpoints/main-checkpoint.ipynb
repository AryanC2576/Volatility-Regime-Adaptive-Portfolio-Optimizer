# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import numpy as np

from dotenv import load_dotenv


# --- CRITICAL FIX ---
# Define the path to the project root and the .env file.
# This makes the script location-independent and ensures the .env file is found.
project_root = os.getcwd()
env_path = os.path.join(project_root, '.env')

# Now, explicitly load the environment variables from that path.
# load_dotenv(dotenv_path=env_path) <-- Older syntax
load_dotenv(dotenv_path=env_path)
# --- END CRITICAL FIX ---

# Add src directory to Python's path
src_path = os.path.join(project_root, 'src')
sys.path.append(src_path)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from config import settings
from src.data_fetcher import fetch_multiple_assets_data, save_data, load_data, get_sample_data # Import get_sample_data
from src.market_analyzer import calculate_returns, calculate_volatility, identify_regimes
from src.strategy_engine import generate_regime_specific_weights
from src.backtester import Backtester
from src.metrics_calculator import get_performance_summary, calculate_cumulative_returns

# --- CRITICAL CHANGE ---
# Update the data file path to use a Pickle file for robustness
settings.RAW_DATA_FILE = os.path.join(settings.DATA_DIR, 'raw_market_data.pkl')
# --- END CRITICAL CHANGE ---

# --- Force yfinance for stability ---
settings.FINANCE_API_SOURCE = 'yfinance'

def run_portfolio_optimizer_backtest():
    """
    Orchestrates the data fetching, strategy application, and backtesting.
    """
    print("--- Starting Volatility-Regime Adaptive Portfolio Optimizer ---")

    # 1. Data Acquisition
    print("\n--- Phase 1: Data Acquisition ---")

    df_raw_data = pd.DataFrame()
    
    # === USE THE SAMPLE DATA HERE TO BYPASS THE API ===
    # You can comment out this line and use the API calls below once you've debugged.
    df_raw_data = get_sample_data()

    # if os.path.exists(settings.RAW_DATA_FILE):
    #     df_raw_data = load_data(settings.RAW_DATA_FILE)
    #
    # if df_raw_data.empty:
    #     print("Data is not valid or not found. Forcing a re-fetch of data...")
    #     df_raw_data = fetch_multiple_assets_data(
    #         symbols=settings.ASSET_SYMBOLS,
    #         start_date=settings.START_DATE,
    #         end_date=settings.END_DATE
    #     )
    #     if df_raw_data.empty:
    #         print("Failed to acquire raw data. Exiting.")
    #         return
    #     save_data(df_raw_data, settings.RAW_DATA_FILE)


    min_required_rows = max(settings.VOL_WINDOW, settings.OPTIMIZATION_WINDOW)
    if len(df_raw_data) < min_required_rows:
        print(f"Not enough historical data for the specified windows. Need at least {min_required_rows} rows.")
        return
    
    # 2. Market Analysis & Feature Engineering
    print("\n--- Phase 2: Market Analysis & Feature Engineering ---")

    try:
        df_close_prices = df_raw_data.xs('Close', level=1, axis=1)
    except KeyError:
        print("Warning: 'Close' not found in MultiIndex. This suggests an issue with data loading. Exiting.")
        return
    
    if df_close_prices.empty:
        print("Error: Close price data not found in raw data. Exiting.")
        return
    
    df_asset_returns = calculate_returns(df_close_prices)

    df_volatility = calculate_volatility(df_asset_returns)
    df_market_features = pd.DataFrame(df_volatility, columns=['Volatility'])

    df_market_features['Regime'] = identify_regimes(df_market_features, vol_col='Volatility')
    
    df_features_and_returns = pd.merge(
        df_asset_returns,
        df_market_features[['Regime', 'Volatility']],
        left_index=True, right_index=True,
        how='inner'
    )
    df_features_and_returns = df_features_and_returns.dropna()

    try:
        if settings.ASSET_SYMBOLS[0] in df_close_prices.columns:
            df_benchmark_prices = df_close_prices[settings.ASSET_SYMBOLS[0]]
        else:
            df_benchmark_prices = df_close_prices.mean(axis=1)
            print("Using average of asset prices as benchmark.")
    except KeyError:
        print(f"KeyError while selecting benchmark. Using average of all close prices.")
        df_benchmark_prices = df_close_prices.mean(axis=1)
    
    df_benchmark_prices = df_benchmark_prices.loc[df_features_and_returns.index]

    # 3. Strategy Application & Backtesting
    print("\n--- Phase 3: Strategy Application & Backtesting ---")
    backtester = Backtester(
        initial_capital=settings.INITIAL_CAPITAL,
        transaction_cost_bps=settings.TRANSACTION_COST_BPS,
        slippage_bps=settings.SLIPPAGE_BPS
    )

    optimal_weights_history = []
    
    df_backtest_prices = df_close_prices.loc[df_features_and_returns.index]
    
    backtest_start_index = settings.OPTIMIZATION_WINDOW -1
    
    if backtest_start_index >= len(df_features_and_returns):
        print("Not enough data points after feature engineering for backtesting window.")
        return

    for i in range(backtest_start_index, len(df_features_and_returns)):
        current_date = df_features_and_returns.index[i]
        
        current_regime = df_features_and_returns.loc[current_date, 'Regime']

        lookback_end_date = df_features_and_returns.index[i-1] if i > 0 else current_date
        lookback_start_date = df_features_and_returns.index[i - settings.OPTIMIZATION_WINDOW]
        
        lookback_returns_data = df_asset_returns.loc[lookback_start_date:lookback_end_date]

        optimal_weights = generate_regime_specific_weights(
            current_regime=current_regime,
            lookback_returns=lookback_returns_data
        )
        optimal_weights_history.append({'Date': current_date, **{s: w for s, w in zip(df_asset_returns.columns, optimal_weights)}})
    
    df_weights = pd.DataFrame(optimal_weights_history).set_index('Date')
    df_weights = df_weights.reindex(df_backtest_prices.index)

    portfolio_history_df = backtester.run_backtest(df_backtest_prices, df_weights)

    # 4. Performance Calculation & Summary
    print("\n--- Phase 4: Performance Calculation & Summary ---")
    if portfolio_history_df.empty:
        print("Portfolio history is empty. Cannot calculate performance.")
        return

    benchmark_aligned_prices = df_benchmark_prices.reindex(portfolio_history_df.index).dropna()
    
    performance_summary = get_performance_summary(
        portfolio_history_df['Total_Value'],
        benchmark_aligned_prices,
        risk_free_rate_annual=settings.RISK_FREE_RATE_ANNUAL
    )

    print("\n--- Performance Summary ---")
    for k, v in performance_summary.items():
        if isinstance(v, (float, np.float64)):
            print(f"{k}: {v:.4f}")
        else:
            print(f"{k}: {v}")

    # 5. Visualization (Basic plots here, dashboard in app/)
    print("\n--- Phase 5: Visualization ---")

    plt.figure(figsize=(14, 7))
    plt.plot(calculate_cumulative_returns(calculate_returns(portfolio_history_df['Total_Value'])), label='Strategy Cumulative Return')
    plt.plot(calculate_cumulative_returns(calculate_returns(benchmark_aligned_prices)), label='Benchmark Cumulative Return')
    plt.title('Cumulative Performance: Strategy vs. Benchmark')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(14, 7))
    main_asset_prices = df_close_prices[settings.ASSET_SYMBOLS[0]].loc[df_features_and_returns.index]
    
    plt.plot(main_asset_prices, label=f'{settings.ASSET_SYMBOLS[0]} Close Price', alpha=0.7)
    
    regime_colors = {'Low_Vol': 'green', 'Normal_Vol': 'blue', 'High_Vol': 'red'}
    for regime, color in regime_colors.items():
        regime_dates = df_market_features.index[df_market_features['Regime'] == regime]
        regime_dates = regime_dates[regime_dates.isin(main_asset_prices.index)]
        if not regime_dates.empty:
            plt.scatter(regime_dates, main_asset_prices.loc[regime_dates],
                        color=color, label=f'{regime} Regime', alpha=0.3, s=20)
    
    plt.title(f'{settings.ASSET_SYMBOLS[0]} Price with Volatility Regimes')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


if __name__ == "__main__":
    run_portfolio_optimizer_backtest()
# Out:
# --- Starting Volatility-Regime Adaptive Portfolio Optimizer ---
#
# --- Phase 1: Data Acquisition ---
# Warning: Using hardcoded sample data for debugging purposes.
#
# --- Phase 2: Market Analysis & Feature Engineering ---
# Calculated logarithmic returns.
# Calculated rolling daily volatility over 20 days.
# Identified volatility regimes.
#
# --- Phase 3: Strategy Application & Backtesting ---
# Warning: No lookback returns for regime Normal_Vol. Returning equal weights.
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for LOW VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# Generating weights for NORMAL VOLATILITY regime.
# Error during optimization: 'str' object has no attribute 'get'
# ...
# Warning: Insufficient cash to buy 7.94 of VNQ on 2021-03-18
# Warning: Insufficient cash to buy 7.10 of QQQ on 2021-03-19
# Warning: Insufficient cash to buy 0.03 of VNQ on 2021-03-22
# Warning: Insufficient cash to buy 11.00 of SPY on 2021-03-23
# Warning: Insufficient cash to buy 1.26 of QQQ on 2021-03-24
# Warning: Insufficient cash to buy 3.60 of TLT on 2021-03-24
# Warning: Insufficient cash to buy 5.61 of SPY on 2021-03-25
# Warning: Insufficient cash to buy 9.33 of SPY on 2021-03-26
# Warning: Insufficient cash to buy 8.81 of SPY on 2021-03-30
# Warning: Insufficient cash to buy 5.37 of QQQ on 2021-03-30
# Warning: Insufficient cash to buy 7.56 of TLT on 2021-03-31
# Warning: Insufficient cash to buy 2.74 of VNQ on 2021-04-01
# Warning: Insufficient cash to buy 14.90 of VNQ on 2021-04-02
# Warning: Insufficient cash to buy 0.16 of SPY on 2021-04-06
# Warning: Insufficient cash to buy 0.36 of QQQ on 2021-04-06
# Warning: Insufficient cash to buy 8.63 of TLT on 2021-04-06
# Warning: Insufficient cash to buy 10.04 of EEM on 2021-04-07
# Warning: Insufficient cash to buy 9.57 of GLD on 2021-04-08
# Warning: Insufficient cash to buy 1.38 of VNQ on 2021-04-09
# Warning: Insufficient cash to buy 2.68 of SPY on 2021-04-12
# Warning: Insufficient cash to buy 15.76 of QQQ on 2021-04-12
# Warning: Insufficient cash to buy 7.27 of EEM on 2021-04-12
# Warning: Insufficient cash to buy 7.63 of VNQ on 2021-04-13
# Warning: Insufficient cash to buy 4.98 of SPY on 2021-04-15
# Warning: Insufficient cash to buy 11.59 of SPY on 2021-04-16
# Warning: Insufficient cash to buy 4.79 of QQQ on 2021-04-19
# Warning: Insufficient cash to buy 9.93 of SPY on 2021-04-20
# Warning: Insufficient cash to buy 16.45 of SPY on 2021-04-21
# Warning: Insufficient cash to buy 30.68 of SPY on 2021-04-22
# Warning: Insufficient cash to buy 32.94 of SPY on 2021-04-23
# Warning: Insufficient cash to buy 6.16 of QQQ on 2021-04-26
# Warning: Insufficient cash to buy 10.43 of GLD on 2021-04-26
# Warning: Insufficient cash to buy 3.77 of QQQ on 2021-04-28
# Warning: Insufficient cash to buy 5.89 of GLD on 2021-04-28
# Warning: Insufficient cash to buy 17.31 of EEM on 2021-04-29
# Warning: Insufficient cash to buy 22.95 of EEM on 2021-04-30
# Warning: Insufficient cash to buy 22.74 of EEM on 2021-05-03
# Warning: Insufficient cash to buy 26.68 of EEM on 2021-05-04
# Warning: Insufficient cash to buy 33.18 of EEM on 2021-05-05
# Warning: Insufficient cash to buy 12.33 of GLD on 2021-05-07
# Warning: Insufficient cash to buy 9.44 of TLT on 2021-05-07
# Warning: Insufficient cash to buy 8.04 of TLT on 2021-05-10
# Warning: Insufficient cash to buy 7.92 of VNQ on 2021-05-11
# Warning: Insufficient cash to buy 5.38 of QQQ on 2021-05-12
# Warning: Insufficient cash to buy 7.63 of GLD on 2021-05-12
# Warning: Insufficient cash to buy 5.70 of TLT on 2021-05-13
# Warning: Insufficient cash to buy 17.84 of TLT on 2021-05-14
# Warning: Insufficient cash to buy 22.68 of SPY on 2021-05-17
# Warning: Insufficient cash to buy 28.93 of SPY on 2021-05-18
# Warning: Insufficient cash to buy 4.51 of QQQ on 2021-05-19
# Warning: Insufficient cash to buy 8.43 of GLD on 2021-05-19
# Warning: Insufficient cash to buy 12.91 of QQQ on 2021-05-20
# Warning: Insufficient cash to buy 14.35 of GLD on 2021-05-20
# Warning: Insufficient cash to buy 19.07 of GLD on 2021-05-21
# Warning: Insufficient cash to buy 15.82 of SPY on 2021-05-25
# Warning: Insufficient cash to buy 8.85 of QQQ on 2021-05-26
# Warning: Insufficient cash to buy 12.15 of QQQ on 2021-05-27
# Warning: Insufficient cash to buy 7.59 of TLT on 2021-05-27
# Warning: Insufficient cash to buy 13.18 of VNQ on 2021-05-28
# Warning: Insufficient cash to buy 14.93 of SPY on 2021-05-31
# Warning: Insufficient cash to buy 15.61 of GLD on 2021-06-02
# Warning: Insufficient cash to buy 0.18 of SPY on 2021-06-04
# Warning: Insufficient cash to buy 14.98 of GLD on 2021-06-04
# Warning: Insufficient cash to buy 6.34 of VNQ on 2021-06-07
# Warning: Insufficient cash to buy 7.64 of SPY on 2021-06-08
# Warning: Insufficient cash to buy 16.06 of GLD on 2021-06-08
# Warning: Insufficient cash to buy 4.31 of EEM on 2021-06-09
# Warning: Insufficient cash to buy 7.43 of QQQ on 2021-06-10
# Warning: Insufficient cash to buy 6.97 of QQQ on 2021-06-11
# Warning: Insufficient cash to buy 5.79 of GLD on 2021-06-11
# Warning: Insufficient cash to buy 6.81 of TLT on 2021-06-14
# Warning: Insufficient cash to buy 15.98 of GLD on 2021-06-15
# Warning: Insufficient cash to buy 15.76 of GLD on 2021-06-16
# Warning: Insufficient cash to buy 15.03 of GLD on 2021-06-17
# Warning: Insufficient cash to buy 10.60 of EEM on 2021-06-18
# Warning: Insufficient cash to buy 11.01 of EEM on 2021-06-21
# Warning: Insufficient cash to buy 8.40 of QQQ on 2021-06-22
# Warning: Insufficient cash to buy 18.13 of QQQ on 2021-06-23
# Warning: Insufficient cash to buy 7.68 of TLT on 2021-06-24
# Warning: Insufficient cash to buy 8.64 of EEM on 2021-06-29
# Warning: Insufficient cash to buy 12.47 of GLD on 2021-06-30
# Warning: Insufficient cash to buy 11.26 of SPY on 2021-07-02
# Warning: Insufficient cash to buy 1.24 of QQQ on 2021-07-02
# Warning: Insufficient cash to buy 2.23 of GLD on 2021-07-02
# Warning: Insufficient cash to buy 19.21 of SPY on 2021-07-05
# Warning: Insufficient cash to buy 11.29 of EEM on 2021-07-07
# Warning: Insufficient cash to buy 6.58 of SPY on 2021-07-09
# Warning: Insufficient cash to buy 6.48 of QQQ on 2021-07-09
# Warning: Insufficient cash to buy 4.72 of GLD on 2021-07-09
# Warning: Insufficient cash to buy 12.67 of QQQ on 2021-07-12
# Warning: Insufficient cash to buy 5.97 of GLD on 2021-07-13
# Warning: Insufficient cash to buy 16.27 of TLT on 2021-07-13
# Warning: Insufficient cash to buy 7.37 of TLT on 2021-07-14
# Warning: Insufficient cash to buy 13.13 of GLD on 2021-07-15
# Warning: Insufficient cash to buy 9.30 of TLT on 2021-07-15
# Warning: Insufficient cash to buy 3.52 of TLT on 2021-07-16
# Warning: Insufficient cash to buy 7.52 of GLD on 2021-07-20
# Warning: Insufficient cash to buy 6.04 of SPY on 2021-07-22
# Warning: Insufficient cash to buy 10.48 of QQQ on 2021-07-22
# Warning: Insufficient cash to buy 12.64 of EEM on 2021-07-23
# Warning: Insufficient cash to buy 4.55 of SPY on 2021-07-28
# Warning: Insufficient cash to buy 4.57 of GLD on 2021-07-28
# Warning: Insufficient cash to buy 11.34 of SPY on 2021-07-29
# Warning: Insufficient cash to buy 20.96 of SPY on 2021-07-30
# Warning: Insufficient cash to buy 3.24 of VNQ on 2021-08-02
# Warning: Insufficient cash to buy 4.46 of SPY on 2021-08-05
# Warning: Insufficient cash to buy 15.87 of GLD on 2021-08-06
# Warning: Insufficient cash to buy 8.92 of GLD on 2021-08-09
# Warning: Insufficient cash to buy 5.79 of TLT on 2021-08-09
# Warning: Insufficient cash to buy 8.42 of TLT on 2021-08-10
# Warning: Insufficient cash to buy 6.28 of EEM on 2021-08-10
# Warning: Insufficient cash to buy 4.58 of QQQ on 2021-08-13
# Warning: Insufficient cash to buy 5.68 of GLD on 2021-08-13
# Warning: Insufficient cash to buy 2.34 of TLT on 2021-08-13
# Warning: Insufficient cash to buy 25.36 of SPY on 2021-08-16
# Warning: Insufficient cash to buy 6.17 of GLD on 2021-08-18
# Warning: Insufficient cash to buy 2.77 of SPY on 2021-08-20
# Warning: Insufficient cash to buy 1.68 of QQQ on 2021-08-20
# Warning: Insufficient cash to buy 9.54 of GLD on 2021-08-23
# Warning: Insufficient cash to buy 8.65 of EEM on 2021-08-23
# Warning: Insufficient cash to buy 15.00 of EEM on 2021-08-24
# Warning: Insufficient cash to buy 8.12 of GLD on 2021-08-26
# Warning: Insufficient cash to buy 12.90 of EEM on 2021-08-26
# Warning: Insufficient cash to buy 8.22 of QQQ on 2021-08-30
# Warning: Insufficient cash to buy 2.19 of VNQ on 2021-08-31
# Warning: Insufficient cash to buy 14.91 of EEM on 2021-09-01
# Warning: Insufficient cash to buy 17.50 of EEM on 2021-09-02
# Warning: Insufficient cash to buy 19.97 of EEM on 2021-09-03
# Warning: Insufficient cash to buy 32.17 of EEM on 2021-09-06
# Warning: Insufficient cash to buy 34.88 of EEM on 2021-09-07
# Warning: Insufficient cash to buy 6.03 of EEM on 2021-09-08
# Warning: Insufficient cash to buy 10.15 of GLD on 2021-09-09
# Warning: Insufficient cash to buy 9.77 of EEM on 2021-09-09
# Warning: Insufficient cash to buy 3.08 of SPY on 2021-09-13
# Warning: Insufficient cash to buy 15.80 of SPY on 2021-09-15
# Warning: Insufficient cash to buy 1.87 of QQQ on 2021-09-15
# Warning: Insufficient cash to buy 3.38 of GLD on 2021-09-15
# Warning: Insufficient cash to buy 18.70 of QQQ on 2021-09-16
# Warning: Insufficient cash to buy 2.07 of VNQ on 2021-09-20
# Warning: Insufficient cash to buy 3.83 of SPY on 2021-09-21
# Warning: Insufficient cash to buy 15.36 of EEM on 2021-09-22
# Warning: Insufficient cash to buy 22.81 of GLD on 2021-09-23
# Warning: Insufficient cash to buy 7.77 of TLT on 2021-09-23
# Warning: Insufficient cash to buy 29.60 of GLD on 2021-09-24
# Warning: Insufficient cash to buy 37.01 of GLD on 2021-09-27
# Warning: Insufficient cash to buy 49.90 of GLD on 2021-09-28
# Warning: Insufficient cash to buy 3.82 of EEM on 2021-09-29
# Warning: Insufficient cash to buy 15.35 of VNQ on 2021-09-30
# Warning: Insufficient cash to buy 9.57 of GLD on 2021-10-04
# Warning: Insufficient cash to buy 15.80 of TLT on 2021-10-04
# Warning: Insufficient cash to buy 16.77 of TLT on 2021-10-05
# Warning: Insufficient cash to buy 5.67 of SPY on 2021-10-07
# Warning: Insufficient cash to buy 7.36 of QQQ on 2021-10-08
# Warning: Insufficient cash to buy 4.04 of GLD on 2021-10-08
# Warning: Insufficient cash to buy 16.11 of GLD on 2021-10-11
# Warning: Insufficient cash to buy 3.87 of TLT on 2021-10-11
# Warning: Insufficient cash to buy 14.13 of TLT on 2021-10-12
# Warning: Insufficient cash to buy 10.53 of TLT on 2021-10-13
# Warning: Insufficient cash to buy 14.48 of QQQ on 2021-10-14
# Warning: Insufficient cash to buy 15.30 of QQQ on 2021-10-15
# Warning: Insufficient cash to buy 20.42 of QQQ on 2021-10-18
# Warning: Insufficient cash to buy 12.18 of GLD on 2021-10-19
# Warning: Insufficient cash to buy 13.66 of GLD on 2021-10-20
# Warning: Insufficient cash to buy 13.00 of GLD on 2021-10-21
# Warning: Insufficient cash to buy 11.41 of VNQ on 2021-10-22
# Warning: Insufficient cash to buy 7.71 of VNQ on 2021-10-25
# Warning: Insufficient cash to buy 1.30 of SPY on 2021-10-27
# Warning: Insufficient cash to buy 2.72 of QQQ on 2021-10-27
# Warning: Insufficient cash to buy 14.83 of SPY on 2021-10-28
# Warning: Insufficient cash to buy 17.75 of SPY on 2021-10-29
# Warning: Insufficient cash to buy 18.66 of SPY on 2021-11-01
# Warning: Insufficient cash to buy 22.71 of SPY on 2021-11-02
# Warning: Insufficient cash to buy 9.30 of QQQ on 2021-11-03
# Warning: Insufficient cash to buy 12.13 of GLD on 2021-11-04
# Warning: Insufficient cash to buy 7.68 of EEM on 2021-11-04
# Warning: Insufficient cash to buy 11.09 of QQQ on 2021-11-08
# Warning: Insufficient cash to buy 10.54 of GLD on 2021-11-08
# Warning: Insufficient cash to buy 4.06 of TLT on 2021-11-09
# Warning: Insufficient cash to buy 2.77 of EEM on 2021-11-09
# Warning: Insufficient cash to buy 6.29 of QQQ on 2021-11-10
# Warning: Insufficient cash to buy 9.22 of TLT on 2021-11-10
# Warning: Insufficient cash to buy 11.31 of GLD on 2021-11-11
# Warning: Insufficient cash to buy 11.19 of GLD on 2021-11-12
# Warning: Insufficient cash to buy 14.66 of SPY on 2021-11-15
# Warning: Insufficient cash to buy 16.31 of GLD on 2021-11-15
# Warning: Insufficient cash to buy 22.02 of GLD on 2021-11-16
# Warning: Insufficient cash to buy 12.04 of EEM on 2021-11-17
# Warning: Insufficient cash to buy 12.00 of EEM on 2021-11-18
# Warning: Insufficient cash to buy 15.15 of SPY on 2021-11-19
# Warning: Insufficient cash to buy 11.72 of QQQ on 2021-11-19
# Warning: Insufficient cash to buy 15.87 of QQQ on 2021-11-22
# Warning: Insufficient cash to buy 14.40 of QQQ on 2021-11-23
# Warning: Insufficient cash to buy 17.39 of QQQ on 2021-11-24
# Warning: Insufficient cash to buy 11.94 of QQQ on 2021-11-25
# Warning: Insufficient cash to buy 23.20 of QQQ on 2021-11-26
# Warning: Insufficient cash to buy 8.23 of TLT on 2021-11-29
# Warning: Insufficient cash to buy 2.50 of SPY on 2021-12-01
# Warning: Insufficient cash to buy 3.51 of QQQ on 2021-12-01
# Warning: Insufficient cash to buy 1.72 of GLD on 2021-12-01
# Warning: Insufficient cash to buy 4.72 of VNQ on 2021-12-02
# Warning: Insufficient cash to buy 10.34 of SPY on 2021-12-03
# Warning: Insufficient cash to buy 9.56 of EEM on 2021-12-06
# Warning: Insufficient cash to buy 18.85 of EEM on 2021-12-07
# Warning: Insufficient cash to buy 4.27 of EEM on 2021-12-09
# Warning: Insufficient cash to buy 5.21 of EEM on 2021-12-10
# Warning: Insufficient cash to buy 11.03 of SPY on 2021-12-13
# Warning: Insufficient cash to buy 9.17 of TLT on 2021-12-13
# Warning: Insufficient cash to buy 9.04 of GLD on 2021-12-14
# Warning: Insufficient cash to buy 7.65 of EEM on 2021-12-14
# Warning: Insufficient cash to buy 22.64 of EEM on 2021-12-15
# Warning: Insufficient cash to buy 27.57 of EEM on 2021-12-16
# Warning: Insufficient cash to buy 34.96 of EEM on 2021-12-17
# Warning: Insufficient cash to buy 39.98 of EEM on 2021-12-20
# Warning: Insufficient cash to buy 5.72 of GLD on 2021-12-22
# Warning: Insufficient cash to buy 16.17 of TLT on 2021-12-22
# Warning: Insufficient cash to buy 5.45 of QQQ on 2021-12-24
# Warning: Insufficient cash to buy 14.83 of TLT on 2021-12-24
# Warning: Insufficient cash to buy 5.31 of VNQ on 2021-12-28
# Warning: Insufficient cash to buy 5.58 of SPY on 2021-12-30
# Warning: Insufficient cash to buy 4.64 of GLD on 2021-12-30
# Warning: Insufficient cash to buy 4.78 of VNQ on 2021-12-31
# Backtest simulation completed with realistic share-based rebalancing.
#
# --- Phase 4: Performance Calculation & Summary ---
#
# --- Performance Summary ---
# Cumulative Return (Strategy): 0.9999
# Cumulative Return (Benchmark): 0.9502
# Annualized Return (Strategy): 0.0005
# Annualized Return (Benchmark): -0.0258
# Annualized Volatility (Strategy): 0.0329
# Annualized Volatility (Benchmark): 0.0808
# Max Drawdown (Strategy): -0.0542
# Max Drawdown (Benchmark): -0.1641
# Sharpe Ratio (Strategy): -0.5876
# Sharpe Ratio (Benchmark): -0.5646
# Calmar Ratio (Strategy): 0.0090
# Calmar Ratio (Benchmark): -0.1572
# Sortino Ratio (Strategy): -0.9744
# Sortino Ratio (Benchmark): -0.9089
#
# --- Phase 5: Visualization ---
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20048\2521197111.py in ?()
#     185     plt.show()
#     186
#     187
#     188 if __name__ == "__main__":
# --> 189     run_portfolio_optimizer_backtest()
#
# ~\AppData\Local\Temp\ipykernel_20048\2521197111.py in ?()
#     152     # 5. Visualization (Basic plots here, dashboard in app/)
#     153     print("\n--- Phase 5: Visualization ---")
#     154
#     155     plt.figure(figsize=(14, 7))
# --> 156     plt.plot(calculate_cumulative_returns(calculate_returns(portfolio_history_df['Total_Value'])), label='Strategy Cumulative Return')
#     157     plt.plot(calculate_cumulative_returns(calculate_returns(benchmark_aligned_prices)), label='Benchmark Cumulative Return')
#     158     plt.title('Cumulative Performance: Strategy vs. Benchmark')
#     159     plt.xlabel('Date')
#
# ~\Desktop\quant_fin\volatility_regime\src\market_analyzer.py in ?(df_prices)
#       8     Input df_prices should be a DataFrame with asset symbols as columns.
#       9     """
#      10     # The check for MultiIndex is removed because main.py now passes a single-level df.
#      11     log_returns = pd.DataFrame(index=df_prices.index)
# ---> 12     for symbol in df_prices.columns:
#      13         if symbol in df_prices.columns: # Check is redundant but safe
#      14             log_returns[symbol] = np.log(df_prices[symbol] / df_prices[symbol].shift(1))
#      15         else:
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'
